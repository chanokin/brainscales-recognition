# %%
# %matplotlib inline
import numpy as np
import matplotlib.pyplot as plt
import os

data = np.load('./run_results/data_gen0_ind0.npz')

# %%
keys = data.keys()
print(keys)
# for k in keys:
#     print(k)
#     print(type(k))
#     print(data[k])
# Out:
# ['recs', 'weights', 'in_labels', 'in_spikes']

# %%
in_labels = data['in_labels'].item()
print(in_labels)
# Out:
# 0

# %%
in_spikes = data['in_spikes'].item()
count = 0
plt.figure()
for lyr in in_spikes:
    spk = in_spikes[lyr]
    for nid, times in enumerate(spk):
        plt.plot(times, np.ones_like(times)*nid + count, '.b', markersize=3)
    count += len(spk)
    plt.axhline(count, color='gray', linestyle='--', linewidth=1.)
plt.show()

# %%
for lyr in sorted(in_spikes.keys()):
    s1 = in_spikes[lyr]
    w, h = (28, 28) if lyr < 2 else ((28//5)+1, (28//3)+1)
    dt = 1#ms
    total_t = 15
    num_images = int(np.ceil(total_t/float(dt)))
    imgs = [np.zeros((h, w)) for _ in range(num_images)]
    for idx, times in enumerate(s1):
        for t in times:
            r, c = int(idx//w), int(idx%w)
            imgs[int(t // dt)][r, c] += 1.0
    fw = 2
    plt.figure(figsize=(total_t*fw, fw))
    for idx, img in enumerate(imgs):
        ax = plt.subplot(1, total_t, idx+1)
        plt.imshow(img)
    plt.show()

# %%
recordings = data['recs'].item()
gabor = recordings['gabor']
# for lyr in gabor:
#     for r in gabor[lyr]:
#         for c in gabor[lyr][r]:
#             print(lyr, r, c, gabor[lyr][r][c]['spikes'])

# %%
out = recordings['output']
print(out)
# Out:
# {0: {u'spikes': [[], [], [], [], [], [], [], [], [], []], u'voltage': [[]]}}

# %%
weights = data['weights'].item()
print(weights.keys())
wgabor = weights['input to gabor']
# print(wgabor)
for lyr in wgabor.keys()[:1]:
    for r in wgabor[lyr].keys()[:]:
        for c in wgabor[lyr][r].keys()[:]:
            img = np.zeros((28, 28, 3))

            for x in wgabor[lyr][r][c]:
                ch = 0 if x == u'inh' else 1
                print(lyr, r, c, x, ch, len(wgabor[lyr][r][c][x]))
                for i, w in enumerate(wgabor[lyr][r][c][x]):
                    if not np.isnan(w[0]):
                        img[i//28, i%28, ch] = np.abs(w[0])
                        
            plt.figure()
            plt.imshow(img/np.max(np.abs(img)))
            plt.show()
# Out:
# [u'input to gabor', u'mushroom to output', u'gabor to mushroom']
# (0, 0, 0, u'inh', 0, 784)
# (0, 0, 0, u'exc', 1, 784)
# (0, 0, 1, u'inh', 0, 784)
# (0, 0, 1, u'exc', 1, 784)
# (0, 0, 2, u'inh', 0, 784)
# (0, 0, 2, u'exc', 1, 784)
# (0, 0, 3, u'inh', 0, 784)
# (0, 0, 3, u'exc', 1, 784)
# (0, 0, 4, u'inh', 0, 784)
# (0, 0, 4, u'exc', 1, 784)
# (0, 0, 5, u'inh', 0, 784)
# (0, 0, 5, u'exc', 1, 784)
# (0, 0, 6, u'inh', 0, 784)
# (0, 0, 6, u'exc', 1, 784)
# (0, 0, 7, u'inh', 0, 784)
# (0, 0, 7, u'exc', 1, 784)
# (0, 0, 8, u'inh', 0, 784)
# (0, 0, 8, u'exc', 1, 784)
# (0, 1, 0, u'inh', 0, 784)
# (0, 1, 0, u'exc', 1, 784)
# (0, 1, 1, u'inh', 0, 784)
# (0, 1, 1, u'exc', 1, 784)
# (0, 1, 2, u'inh', 0, 784)
# (0, 1, 2, u'exc', 1, 784)
# (0, 1, 3, u'inh', 0, 784)
# (0, 1, 3, u'exc', 1, 784)
# (0, 1, 4, u'inh', 0, 784)
# (0, 1, 4, u'exc', 1, 784)
# (0, 1, 5, u'inh', 0, 784)
# (0, 1, 5, u'exc', 1, 784)
# (0, 1, 6, u'inh', 0, 784)
# (0, 1, 6, u'exc', 1, 784)
# (0, 1, 7, u'inh', 0, 784)
# (0, 1, 7, u'exc', 1, 784)
# (0, 1, 8, u'inh', 0, 784)
# (0, 1, 8, u'exc', 1, 784)
# (0, 2, 0, u'inh', 0, 784)
# (0, 2, 0, u'exc', 1, 784)
# (0, 2, 1, u'inh', 0, 784)
# (0, 2, 1, u'exc', 1, 784)
# (0, 2, 2, u'inh', 0, 784)
# (0, 2, 2, u'exc', 1, 784)
# (0, 2, 3, u'inh', 0, 784)
# (0, 2, 3, u'exc', 1, 784)
# (0, 2, 4, u'inh', 0, 784)
# (0, 2, 4, u'exc', 1, 784)
# (0, 2, 5, u'inh', 0, 784)
# (0, 2, 5, u'exc', 1, 784)
# (0, 2, 6, u'inh', 0, 784)
# (0, 2, 6, u'exc', 1, 784)
# (0, 2, 7, u'inh', 0, 784)
# (0, 2, 7, u'exc', 1, 784)
# (0, 2, 8, u'inh', 0, 784)
# (0, 2, 8, u'exc', 1, 784)
# (0, 3, 0, u'inh', 0, 784)
# (0, 3, 0, u'exc', 1, 784)
# (0, 3, 1, u'inh', 0, 784)
# (0, 3, 1, u'exc', 1, 784)
# (0, 3, 2, u'inh', 0, 784)
# (0, 3, 2, u'exc', 1, 784)
# (0, 3, 3, u'inh', 0, 784)
# (0, 3, 3, u'exc', 1, 784)
# (0, 3, 4, u'inh', 0, 784)
# (0, 3, 4, u'exc', 1, 784)
# (0, 3, 5, u'inh', 0, 784)
# (0, 3, 5, u'exc', 1, 784)
# (0, 3, 6, u'inh', 0, 784)
# (0, 3, 6, u'exc', 1, 784)
# (0, 3, 7, u'inh', 0, 784)
# (0, 3, 7, u'exc', 1, 784)
# (0, 3, 8, u'inh', 0, 784)
# (0, 3, 8, u'exc', 1, 784)
# (0, 4, 0, u'inh', 0, 784)
# (0, 4, 0, u'exc', 1, 784)
# (0, 4, 1, u'inh', 0, 784)
# (0, 4, 1, u'exc', 1, 784)
# (0, 4, 2, u'inh', 0, 784)
# (0, 4, 2, u'exc', 1, 784)
# (0, 4, 3, u'inh', 0, 784)
# (0, 4, 3, u'exc', 1, 784)
# (0, 4, 4, u'inh', 0, 784)
# (0, 4, 4, u'exc', 1, 784)
# (0, 4, 5, u'inh', 0, 784)
# (0, 4, 5, u'exc', 1, 784)
# (0, 4, 6, u'inh', 0, 784)
# (0, 4, 6, u'exc', 1, 784)
# (0, 4, 7, u'inh', 0, 784)
# (0, 4, 7, u'exc', 1, 784)
# (0, 4, 8, u'inh', 0, 784)
# (0, 4, 8, u'exc', 1, 784)
# (0, 5, 0, u'inh', 0, 784)
# (0, 5, 0, u'exc', 1, 784)
# (0, 5, 1, u'inh', 0, 784)
# (0, 5, 1, u'exc', 1, 784)
# (0, 5, 2, u'inh', 0, 784)
# (0, 5, 2, u'exc', 1, 784)
# (0, 5, 3, u'inh', 0, 784)
# (0, 5, 3, u'exc', 1, 784)
# (0, 5, 4, u'inh', 0, 784)
# (0, 5, 4, u'exc', 1, 784)
# (0, 5, 5, u'inh', 0, 784)
# (0, 5, 5, u'exc', 1, 784)
# (0, 5, 6, u'inh', 0, 784)
# (0, 5, 6, u'exc', 1, 784)
# (0, 5, 7, u'inh', 0, 784)
# (0, 5, 7, u'exc', 1, 784)
# (0, 5, 8, u'inh', 0, 784)
# (0, 5, 8, u'exc', 1, 784)
# (0, 6, 0, u'inh', 0, 784)
# (0, 6, 0, u'exc', 1, 784)
# (0, 6, 1, u'inh', 0, 784)
# (0, 6, 1, u'exc', 1, 784)
# (0, 6, 2, u'inh', 0, 784)
# (0, 6, 2, u'exc', 1, 784)
# (0, 6, 3, u'inh', 0, 784)
# (0, 6, 3, u'exc', 1, 784)
# (0, 6, 4, u'inh', 0, 784)
# (0, 6, 4, u'exc', 1, 784)
# (0, 6, 5, u'inh', 0, 784)
# (0, 6, 5, u'exc', 1, 784)
# (0, 6, 6, u'inh', 0, 784)
# (0, 6, 6, u'exc', 1, 784)
# (0, 6, 7, u'inh', 0, 784)
# (0, 6, 7, u'exc', 1, 784)
# (0, 6, 8, u'inh', 0, 784)
# (0, 6, 8, u'exc', 1, 784)
# (0, 7, 0, u'inh', 0, 784)
# (0, 7, 0, u'exc', 1, 784)
# (0, 7, 1, u'inh', 0, 784)
# (0, 7, 1, u'exc', 1, 784)
# (0, 7, 2, u'inh', 0, 784)
# (0, 7, 2, u'exc', 1, 784)
# (0, 7, 3, u'inh', 0, 784)
# (0, 7, 3, u'exc', 1, 784)
# (0, 7, 4, u'inh', 0, 784)
# (0, 7, 4, u'exc', 1, 784)
# (0, 7, 5, u'inh', 0, 784)
# (0, 7, 5, u'exc', 1, 784)
# (0, 7, 6, u'inh', 0, 784)
# (0, 7, 6, u'exc', 1, 784)
# (0, 7, 7, u'inh', 0, 784)
# (0, 7, 7, u'exc', 1, 784)
# (0, 7, 8, u'inh', 0, 784)
# (0, 7, 8, u'exc', 1, 784)
# (0, 8, 0, u'inh', 0, 784)
# (0, 8, 0, u'exc', 1, 784)
# (0, 8, 1, u'inh', 0, 784)
# (0, 8, 1, u'exc', 1, 784)
# (0, 8, 2, u'inh', 0, 784)
# (0, 8, 2, u'exc', 1, 784)
# (0, 8, 3, u'inh', 0, 784)
# (0, 8, 3, u'exc', 1, 784)
# (0, 8, 4, u'inh', 0, 784)
# (0, 8, 4, u'exc', 1, 784)
# (0, 8, 5, u'inh', 0, 784)
# (0, 8, 5, u'exc', 1, 784)
# (0, 8, 6, u'inh', 0, 784)
# (0, 8, 6, u'exc', 1, 784)
# (0, 8, 7, u'inh', 0, 784)
# (0, 8, 7, u'exc', 1, 784)
# (0, 8, 8, u'inh', 0, 784)
# (0, 8, 8, u'exc', 1, 784)
# (0, 9, 0, u'inh', 0, 784)
# (0, 9, 0, u'exc', 1, 784)
# (0, 9, 1, u'inh', 0, 784)
# (0, 9, 1, u'exc', 1, 784)
# (0, 9, 2, u'inh', 0, 784)
# (0, 9, 2, u'exc', 1, 784)
# (0, 9, 3, u'inh', 0, 784)
# (0, 9, 3, u'exc', 1, 784)
# (0, 9, 4, u'inh', 0, 784)
# (0, 9, 4, u'exc', 1, 784)
# (0, 9, 5, u'inh', 0, 784)
# (0, 9, 5, u'exc', 1, 784)
# (0, 9, 6, u'inh', 0, 784)
# (0, 9, 6, u'exc', 1, 784)
# (0, 9, 7, u'inh', 0, 784)
# (0, 9, 7, u'exc', 1, 784)
# (0, 9, 8, u'inh', 0, 784)
# (0, 9, 8, u'exc', 1, 784)
